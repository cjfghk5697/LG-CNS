# %%
# %load_ext autoreload
# %autoreload 2

from util_0805_1 import *
from myalgorithm_0805_1 import algorithm
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## 실험 내용
# 1. 4번들 크루스칼 돌릴 떄 엣지 n개씩만 묶기 -> > 비용 개선 잘 안됨

# %% [markdown]
# ### 모든 데이터셋 실험

# %%
import pandas as pd

# 기본 데이터셋 추가
data_sizes = [50, 100, 200]
problem_files = []
for data_size in data_sizes:
    problem_files.append(fr'C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K{data_size}_1.json')
    problem_files.append(fr'C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K{data_size}_2.json')

# stage 데이터 추가
for file_num in range(1, 19):
    problem_file = fr'C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_{file_num}.json'

    problem_files.append(problem_file)

results = []
solutions = []
for problem_file in problem_files:
    start_time = time.time()

    testcase_name = problem_file.split('\\')[-1].split('.')[0]

    ## ------------------- 기본 변수 할당 ---------------------------

    with open(problem_file, 'r') as f:
        prob = json.load(f)

    K = prob['K']

    ALL_ORDERS = [Order(order_info) for order_info in prob['ORDERS']]
    ALL_RIDERS = [Rider(rider_info) for rider_info in prob['RIDERS']]

    DIST = np.array(prob['DIST'])
    for r in ALL_RIDERS:
        r.T = np.round(DIST/r.speed + r.service_time).astype(int)

    inf = float('inf')

    timelimit = 60

    ## --------------------- 커스텀 코드 시작 ---------------------------

    solution = algorithm(K, ALL_ORDERS, ALL_RIDERS, DIST, timelimit)
    solutions.append(solution)

    end_time = time.time()
    process_time = end_time - start_time

    with open(problem_file, 'r') as f:
        prob = json.load(f)

    K = prob['K']

    ALL_ORDERS = [Order(order_info) for order_info in prob['ORDERS']]
    ALL_RIDERS = [Rider(rider_info) for rider_info in prob['RIDERS']]

    DIST = np.array(prob['DIST'])
    for r in ALL_RIDERS:
        r.T = np.round(DIST/r.speed + r.service_time).astype(int)

    checked_solution = solution_check(K, ALL_ORDERS, ALL_RIDERS, DIST, solution)

    results.append((problem_file, checked_solution['avg_cost']))

    print(testcase_name, process_time, checked_solution['avg_cost'])

df = pd.DataFrame(results, columns=['Name', 'Score'])
# Out:
# TEST_K50_1 0.42406702041625977 3874.616
# TEST_K50_2 0.5529134273529053 4407.222
# TEST_K100_1 1.4175639152526855 3782.165
# TEST_K100_2 1.48069167137146 3872.5249999999996
# TEST_K200_1 4.300882816314697 3501.6884999999997
# TEST_K200_2 4.083242893218994 3379.0569999999993
# STAGE1_1 1.1533992290496826 3909.3439999999996
# STAGE1_2 0.9823925495147705 3600.2080000000005
# STAGE1_3 3.7217214107513428 3160.96
# STAGE1_4 3.6511199474334717 2735.602499999999
# STAGE1_5 8.025406837463379 2488.515666666666
# STAGE1_6 9.451885223388672 2691.101
# STAGE1_7 1.1443686485290527 3597.348
# STAGE1_8 0.9980196952819824 3448.609999999999
# STAGE1_9 4.340079069137573 3316.2999999999993
# STAGE1_10 4.123096466064453 2638.225
# STAGE1_11 8.8717360496521 2655.910666666667
# STAGE1_12 10.073783159255981 2668.221333333333
# STAGE1_13 1.7264726161956787 5195.445999999999
# STAGE1_14 0.9132184982299805 4364.3640000000005
# STAGE1_15 5.036638021469116 4546.987
# ...

# %%
import pandas as pd

# 기본 데이터셋 추가
data_sizes = [50, 100, 200]
problem_files = []
for data_size in data_sizes:
    problem_files.append(fr'C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K{data_size}_1.json')
    problem_files.append(fr'C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K{data_size}_2.json')

# stage 데이터 추가
for file_num in range(1, 19):
    problem_file = fr'C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_{file_num}.json'

    problem_files.append(problem_file)

results = []
solutions = []
for problem_file in problem_files:
    start_time = time.time()

    testcase_name = problem_file.split('\\')[-1].split('.')[0]

    ## ------------------- 기본 변수 할당 ---------------------------

    with open(problem_file, 'r') as f:
        prob = json.load(f)

    K = prob['K']

    ALL_ORDERS = [Order(order_info) for order_info in prob['ORDERS']]
    ALL_RIDERS = [Rider(rider_info) for rider_info in prob['RIDERS']]

    DIST = np.array(prob['DIST'])
    for r in ALL_RIDERS:
        r.T = np.round(DIST/r.speed + r.service_time).astype(int)

    inf = float('inf')

    timelimit = 60

    ## --------------------- 커스텀 코드 시작 ---------------------------

    solution = algorithm(K, ALL_ORDERS, ALL_RIDERS, DIST, timelimit)
    solutions.append(solution)

    end_time = time.time()
    process_time = end_time - start_time

    with open(problem_file, 'r') as f:
        prob = json.load(f)

    K = prob['K']

    ALL_ORDERS = [Order(order_info) for order_info in prob['ORDERS']]
    ALL_RIDERS = [Rider(rider_info) for rider_info in prob['RIDERS']]

    DIST = np.array(prob['DIST'])
    for r in ALL_RIDERS:
        r.T = np.round(DIST/r.speed + r.service_time).astype(int)

    checked_solution = solution_check(K, ALL_ORDERS, ALL_RIDERS, DIST, solution)

    results.append((problem_file, checked_solution['avg_cost']))

    print(testcase_name, process_time, checked_solution['avg_cost'])

df = pd.DataFrame(results, columns=['Name', 'Score'])
# Out:
# TEST_K50_1 0.0815286636352539 3889.176
# TEST_K50_2 0.0770118236541748 4337.129999999999
# TEST_K100_1 0.2125685214996338 3840.19
# TEST_K100_2 0.2496802806854248 3807.398999999999
# TEST_K200_1 0.8381466865539551 3506.015
# TEST_K200_2 0.823723316192627 3289.2819999999997
# STAGE1_1 0.24390268325805664 3904.696
# STAGE1_2 0.24682879447937012 3482.1780000000003
# STAGE1_3 0.8278388977050781 3166.3785
# STAGE1_4 0.8388197422027588 2735.1929999999998
# STAGE1_5 1.7958276271820068 2434.7926666666663
# STAGE1_6 1.910956859588623 2605.5139999999997
# STAGE1_7 0.2376422882080078 3559.578
# STAGE1_8 0.28556156158447266 3405.844
# STAGE1_9 0.8279492855072021 3255.7775
# STAGE1_10 0.8880574703216553 2593.5595000000003
# STAGE1_11 1.9930992126464844 2699.175333333334
# STAGE1_12 2.141662120819092 2653.4396666666667
# STAGE1_13 0.167372465133667 5271.19
# STAGE1_14 0.22976899147033691 4480.668
# STAGE1_15 0.7375075817108154 4549.9575
# STAGE1_16 0.8190701007843018 3480.9750000000004
# ...

# %%
# top_1
TEST_K50_1 0.42406702041625977 3874.616
TEST_K50_2 0.5529134273529053 4407.222
TEST_K100_1 1.4175639152526855 3782.165
TEST_K100_2 1.48069167137146 3872.5249999999996
TEST_K200_1 4.300882816314697 3501.6884999999997
TEST_K200_2 4.083242893218994 3379.0569999999993
STAGE1_1 1.1533992290496826 3909.3439999999996
STAGE1_2 0.9823925495147705 3600.2080000000005
STAGE1_3 3.7217214107513428 3160.96
STAGE1_4 3.6511199474334717 2735.602499999999
STAGE1_5 8.025406837463379 2488.515666666666
STAGE1_6 9.451885223388672 2691.101
STAGE1_7 1.1443686485290527 3597.348
STAGE1_8 0.9980196952819824 3448.609999999999
STAGE1_9 4.340079069137573 3316.2999999999993
STAGE1_10 4.123096466064453 2638.225
STAGE1_11 8.8717360496521 2655.910666666667
STAGE1_12 10.073783159255981 2668.221333333333
STAGE1_13 1.7264726161956787 5195.445999999999
STAGE1_14 0.9132184982299805 4364.3640000000005
STAGE1_15 5.036638021469116 4546.987
STAGE1_16 3.0871379375457764 3453.8410000000003
STAGE1_17 8.424468755722046 3659.251
STAGE1_18 8.213144779205322 3762.920333333333

Top_len(edges)
TEST_K50_1 0.0815286636352539 3889.176
TEST_K50_2 0.0770118236541748 4337.129999999999
TEST_K100_1 0.2125685214996338 3840.19
TEST_K100_2 0.2496802806854248 3807.398999999999
TEST_K200_1 0.8381466865539551 3506.015
TEST_K200_2 0.823723316192627 3289.2819999999997
STAGE1_1 0.24390268325805664 3904.696
STAGE1_2 0.24682879447937012 3482.1780000000003
STAGE1_3 0.8278388977050781 3166.3785
STAGE1_4 0.8388197422027588 2735.1929999999998
STAGE1_5 1.7958276271820068 2434.7926666666663
STAGE1_6 1.910956859588623 2605.5139999999997
STAGE1_7 0.2376422882080078 3559.578
STAGE1_8 0.28556156158447266 3405.844
STAGE1_9 0.8279492855072021 3255.7775
STAGE1_10 0.8880574703216553 2593.5595000000003
STAGE1_11 1.9930992126464844 2699.175333333334
STAGE1_12 2.141662120819092 2653.4396666666667
STAGE1_13 0.167372465133667 5271.19
STAGE1_14 0.22976899147033691 4480.668
STAGE1_15 0.7375075817108154 4549.9575
STAGE1_16 0.8190701007843018 3480.9750000000004
STAGE1_17 1.5259878635406494 3671.663666666667
STAGE1_18 1.7679860591888428 3641.609
