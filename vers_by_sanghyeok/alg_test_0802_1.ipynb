# %%
# %load_ext autoreload
# %autoreload 2

from util_0802_1 import *
from myalgorithm_0802_2 import algorithm as algorithm
from myalgorithm_0802_4 import algorithm as algorithm_no_SA
from myalgorithm_0802_2_2 import algorithm as algorithm_0802_2_2

import pandas as pd

# %% [markdown]
# ## 실험 내용
# - 시우님 코드를 탐색하는 가중치를 늘리는 방식으로 개선하는 방식을 좀 더 확인해보기

# %% [markdown]
# ### 초기 코드

# %%
# 기본 데이터셋 추가
data_sizes = [50, 100, 200]
problem_files = []
for data_size in data_sizes:
    problem_files.append(fr'C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K{data_size}_1.json')
    problem_files.append(fr'C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K{data_size}_2.json')

# stage 데이터 추가
for file_num in range(1, 19):
    problem_file = fr'C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_{file_num}.json'

    problem_files.append(problem_file)

results = []
for problem_file in problem_files:
    ## ------------------- 기본 변수 할당 ---------------------------

    with open(problem_file, 'r') as f:
        prob = json.load(f)

    K = prob['K']

    ALL_ORDERS = [Order(order_info) for order_info in prob['ORDERS']]
    ALL_RIDERS = [Rider(rider_info) for rider_info in prob['RIDERS']]

    DIST = np.array(prob['DIST'])
    for r in ALL_RIDERS:
        r.T = np.round(DIST/r.speed + r.service_time).astype(int)

    inf = float('inf')

    timelimit = 60

    ## --------------------- 커스텀 코드 시작 ---------------------------

    solution = algorithm_init(K, ALL_ORDERS, ALL_RIDERS, DIST, timelimit)

    with open(problem_file, 'r') as f:
        prob = json.load(f)

    K = prob['K']

    ALL_ORDERS = [Order(order_info) for order_info in prob['ORDERS']]
    ALL_RIDERS = [Rider(rider_info) for rider_info in prob['RIDERS']]

    DIST = np.array(prob['DIST'])
    for r in ALL_RIDERS:
        r.T = np.round(DIST/r.speed + r.service_time).astype(int)

    checked_solution = solution_check(K, ALL_ORDERS, ALL_RIDERS, DIST, solution)

    print(problem_file)

    results.append((problem_file, checked_solution['avg_cost']))

df = pd.DataFrame(results, columns=['Name', 'Score'])

df.to_csv('8-1_siwoo_base.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ### 초기 코드 개선 시도

# %%
# 기본 데이터셋 추가
data_sizes = [50, 100, 200]
problem_files = []
for data_size in data_sizes:
    problem_files.append(fr'C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K{data_size}_1.json')
    problem_files.append(fr'C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K{data_size}_2.json')

# stage 데이터 추가
for file_num in range(1, 19):
    problem_file = fr'C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_{file_num}.json'

    problem_files.append(problem_file)

results = []
for problem_file in problem_files:
    ## ------------------- 기본 변수 할당 ---------------------------

    with open(problem_file, 'r') as f:
        prob = json.load(f)

    K = prob['K']

    ALL_ORDERS = [Order(order_info) for order_info in prob['ORDERS']]
    ALL_RIDERS = [Rider(rider_info) for rider_info in prob['RIDERS']]

    DIST = np.array(prob['DIST'])
    for r in ALL_RIDERS:
        r.T = np.round(DIST/r.speed + r.service_time).astype(int)

    inf = float('inf')

    timelimit = 60

    ## --------------------- 커스텀 코드 시작 ---------------------------

    solution = algorithm(K, ALL_ORDERS, ALL_RIDERS, DIST, timelimit)

    with open(problem_file, 'r') as f:
        prob = json.load(f)

    K = prob['K']

    ALL_ORDERS = [Order(order_info) for order_info in prob['ORDERS']]
    ALL_RIDERS = [Rider(rider_info) for rider_info in prob['RIDERS']]

    DIST = np.array(prob['DIST'])
    for r in ALL_RIDERS:
        r.T = np.round(DIST/r.speed + r.service_time).astype(int)

    checked_solution = solution_check(K, ALL_ORDERS, ALL_RIDERS, DIST, solution)

    print(problem_file)

    results.append((problem_file, checked_solution['avg_cost']))

df = pd.DataFrame(results, columns=['Name', 'Score'])

df.to_csv('8-1_siwoo_changed_30sec_OrderCoupleChecked.csv', index=False, encoding='utf-8-sig')
# Out:
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K50_1.json
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K50_2.json
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K100_1.json
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K100_2.json
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K200_1.json
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K200_2.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_1.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_2.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_3.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_4.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_5.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_6.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_7.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_8.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_9.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_10.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_11.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_12.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_13.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_14.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_15.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_16.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_17.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_18.json

# %%
# 기본 데이터셋 추가
data_sizes = [50, 100, 200]
problem_files = []
for data_size in data_sizes:
    problem_files.append(fr'C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K{data_size}_1.json')
    problem_files.append(fr'C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K{data_size}_2.json')

# stage 데이터 추가
for file_num in range(1, 19):
    problem_file = fr'C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_{file_num}.json'

    problem_files.append(problem_file)

results = []
for problem_file in problem_files:
    ## ------------------- 기본 변수 할당 ---------------------------

    with open(problem_file, 'r') as f:
        prob = json.load(f)

    K = prob['K']

    ALL_ORDERS = [Order(order_info) for order_info in prob['ORDERS']]
    ALL_RIDERS = [Rider(rider_info) for rider_info in prob['RIDERS']]

    DIST = np.array(prob['DIST'])
    for r in ALL_RIDERS:
        r.T = np.round(DIST/r.speed + r.service_time).astype(int)

    inf = float('inf')

    timelimit = 60

    ## --------------------- 커스텀 코드 시작 ---------------------------

    solution = algorithm_no_SA(K, ALL_ORDERS, ALL_RIDERS, DIST, timelimit)

    with open(problem_file, 'r') as f:
        prob = json.load(f)

    K = prob['K']

    ALL_ORDERS = [Order(order_info) for order_info in prob['ORDERS']]
    ALL_RIDERS = [Rider(rider_info) for rider_info in prob['RIDERS']]

    DIST = np.array(prob['DIST'])
    for r in ALL_RIDERS:
        r.T = np.round(DIST/r.speed + r.service_time).astype(int)

    checked_solution = solution_check(K, ALL_ORDERS, ALL_RIDERS, DIST, solution)

    print(problem_file)

    results.append((problem_file, checked_solution['avg_cost']))

df = pd.DataFrame(results, columns=['Name', 'Score'])

df.to_csv('8-1_siwoo_changed_30sec_no_SA.csv', index=False, encoding='utf-8-sig')
# Out:
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K50_1.json
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K50_2.json
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K100_1.json
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K100_2.json
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K200_1.json
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K200_2.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_1.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_2.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_3.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_4.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_5.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_6.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_7.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_8.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_9.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_10.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_11.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_12.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_13.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_14.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_15.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_16.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_17.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_18.json

# %% [markdown]
# ### 가중치 탐색을 40초 동안 하는 경우

# %%
# 기본 데이터셋 추가
data_sizes = [50, 100, 200]
problem_files = []
for data_size in data_sizes:
    problem_files.append(fr'C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K{data_size}_1.json')
    problem_files.append(fr'C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K{data_size}_2.json')

# stage 데이터 추가
for file_num in range(1, 19):
    problem_file = fr'C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_{file_num}.json'

    problem_files.append(problem_file)

results = []
for problem_file in problem_files:
    ## ------------------- 기본 변수 할당 ---------------------------

    with open(problem_file, 'r') as f:
        prob = json.load(f)

    K = prob['K']

    ALL_ORDERS = [Order(order_info) for order_info in prob['ORDERS']]
    ALL_RIDERS = [Rider(rider_info) for rider_info in prob['RIDERS']]

    DIST = np.array(prob['DIST'])
    for r in ALL_RIDERS:
        r.T = np.round(DIST/r.speed + r.service_time).astype(int)

    inf = float('inf')

    timelimit = 60

    ## --------------------- 커스텀 코드 시작 ---------------------------

    solution = algorithm(K, ALL_ORDERS, ALL_RIDERS, DIST, timelimit)

    with open(problem_file, 'r') as f:
        prob = json.load(f)

    K = prob['K']

    ALL_ORDERS = [Order(order_info) for order_info in prob['ORDERS']]
    ALL_RIDERS = [Rider(rider_info) for rider_info in prob['RIDERS']]

    DIST = np.array(prob['DIST'])
    for r in ALL_RIDERS:
        r.T = np.round(DIST/r.speed + r.service_time).astype(int)

    checked_solution = solution_check(K, ALL_ORDERS, ALL_RIDERS, DIST, solution)

    print(problem_file)

    results.append((problem_file, checked_solution['avg_cost']))

df = pd.DataFrame(results, columns=['Name', 'Score'])

df.to_csv('8-1_siwoo_changed_40sec.csv', index=False, encoding='utf-8-sig')
# Out:
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K50_1.json
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K50_2.json
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K100_1.json
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K100_2.json
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K200_1.json
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K200_2.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_1.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_2.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_3.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_4.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_5.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_6.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_7.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_8.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_9.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_10.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_11.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_12.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_13.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_14.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_15.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_16.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_17.json
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_18.json

# %% [markdown]
# ### 가중치 탐색을 30초 동안 하는 경우 데이터셋별 가중치 조합 몇 개를 탐색하는지 확인하기

# %%
# 기본 데이터셋 추가
data_sizes = [50, 100, 200]
problem_files = []
for data_size in data_sizes:
    problem_files.append(fr'C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K{data_size}_1.json')
    problem_files.append(fr'C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K{data_size}_2.json')

# stage 데이터 추가
for file_num in range(1, 19):
    problem_file = fr'C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_{file_num}.json'

    problem_files.append(problem_file)

results = []
for problem_file in problem_files:
    ## ------------------- 기본 변수 할당 ---------------------------

    with open(problem_file, 'r') as f:
        prob = json.load(f)

    K = prob['K']

    ALL_ORDERS = [Order(order_info) for order_info in prob['ORDERS']]
    ALL_RIDERS = [Rider(rider_info) for rider_info in prob['RIDERS']]

    DIST = np.array(prob['DIST'])
    for r in ALL_RIDERS:
        r.T = np.round(DIST/r.speed + r.service_time).astype(int)

    inf = float('inf')

    timelimit = 60

    ## --------------------- 커스텀 코드 시작 ---------------------------

    solution, processed_weight_comb_c, process_time = algorithm_0802_2_2(K, ALL_ORDERS, ALL_RIDERS, DIST, timelimit)

    with open(problem_file, 'r') as f:
        prob = json.load(f)

    K = prob['K']

    ALL_ORDERS = [Order(order_info) for order_info in prob['ORDERS']]
    ALL_RIDERS = [Rider(rider_info) for rider_info in prob['RIDERS']]

    DIST = np.array(prob['DIST'])
    for r in ALL_RIDERS:
        r.T = np.round(DIST/r.speed + r.service_time).astype(int)

    checked_solution = solution_check(K, ALL_ORDERS, ALL_RIDERS, DIST, solution)

    print(problem_file, checked_solution['avg_cost'], processed_weight_comb_c, process_time)

    results.append((problem_file, checked_solution['avg_cost'], processed_weight_comb_c, process_time))

df = pd.DataFrame(results, columns=['Name', 'Score', 'Weight Comb Count', 'Process Time'])
# Out:
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K50_1.json 3680.396 1 58.1274197101593
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K50_2.json 4108.114 1 57.45654559135437
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K100_1.json 3499.225 1 57.863137006759644
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K100_2.json 3634.0930000000003 1 57.71591091156006
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K200_1.json 3374.5630000000006 1 58.61492848396301
# C:\Users\hsh80\Desktop\LG CNS\alg_test_problems_20240429\TEST_K200_2.json 3279.8 1 58.68334913253784
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_1.json 3730.52 1 58.853447914123535
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_2.json 3375.1019999999994 1 61.24072575569153
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_3.json 3115.921 1 59.13771390914917
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_4.json 2767.343 1 80.10865807533264
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_5.json 2342.3033333333333 1 59.67507719993591
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_6.json 2580.351999999999 1 70.43904089927673
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_7.json 3518.6369999999997 1 58.27740120887756
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_8.json 3360.1530000000002 1 59.74116492271423
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_9.json 3115.58 1 58.369216203689575
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_10.json 2645.0019999999995 1 65.06126499176025
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_11.json 2529.6616666666678 1 58.45945191383362
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_12.json 2882.6093333333333 1 297.3801462650299
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_13.json 5083.274 1 57.52619791030884
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_14.json 4296.742 1 58.72192025184631
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_15.json 4338.1990000000005 1 57.912286043167114
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_16.json 3353.8515000000007 1 64.41688179969788
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_17.json 3547.1380000000004 1 58.018832206726074
# C:\Users\hsh80\Desktop\LG CNS\stage1_problems\STAGE1_18.json 3768.49 1 66.22919654846191
